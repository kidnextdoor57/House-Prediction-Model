# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import numpy as np

# %%
df = pd.read_csv("FuelConsumption.csv")
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1062    False
# 1063    False
# 1064    False
# 1065    False
# 1066    False
# Length: 1067, dtype: bool

# %%
x = df['CO2EMISSIONS']
y = df['VEHICLECLASS']

# %%
y.head()
# Out:
# 0        COMPACT
# 1        COMPACT
# 2        COMPACT
# 3    SUV - SMALL
# 4    SUV - SMALL
# Name: VEHICLECLASS, dtype: object

# %%
x.head()
# Out:
# 0    196
# 1    221
# 2    136
# 3    255
# 4    244
# Name: CO2EMISSIONS, dtype: int64

# %%
model = LogisticRegression()

# %%
model.fit(x.values, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.fit(x.values, y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1222, in LogisticRegression.fit(self, X, y, sample_weight)
#    1219 else:
#    1220     _dtype = [np.float64, np.float32]
# -> 1222 X, y = validate_data(
#    1223     self,
#    1224     X,
#    1225     y,
#    1226     accept_sparse="csr",
#    1227     dtype=_dtype,
#    1228     order="C",
# ...

# %% [markdown]
# ## HOUSE PRICE PREDICTION

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pylab as plt
import seaborn as sns

# %%
df2 = pd.read_csv('housing.csv')
df2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# counting the number of values under a column
df2.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df2.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df2.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# removes missing values
df2= df2.dropna()
df2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df2.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
w = df2.drop(columns = ['median_house_value'] )
u = df2[['median_house_value']]

# %%
df2.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
dfing = df2[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value']]
dfing.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# latitude                 -0.066983   -0.108997   -0.071774      -0.079626
# ...

# %%
sns.heatmap(dfing.corr(), annot = True)
# Out:
# <Axes: >

# %%
# transforming a categorical data to numerical data, and the dtype is to make sure they are in intergers
dop = pd.get_dummies(df2[['ocean_proximity']], dtype = int)

# %%
# joining two dataframe tables together
new_data = w.join(dop)
new_data = new_data.drop(columns = ['ocean_proximity'], axis= 1)
new_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#counting how mnay times a data appeared under a column
new_data['ocean_proximity_NEAR BAY'].value_counts()
# Out:
# ocean_proximity_NEAR BAY
# 0    18163
# 1     2270
# Name: count, dtype: int64

# %%
# checking the data types of the columns
print(new_data.dtypes)
# Out:
# longitude                     float64
# latitude                      float64
# housing_median_age            float64
# total_rooms                   float64
# total_bedrooms                float64
# population                    float64
# households                    float64
# median_income                 float64
# ocean_proximity_<1H OCEAN       int64
# ocean_proximity_INLAND          int64
# ocean_proximity_ISLAND          int64
# ocean_proximity_NEAR BAY        int64
# ocean_proximity_NEAR OCEAN      int64
# dtype: object

# %%
new_data = new_data.dropna()

# %%
# shows correlation with data in a dataframe
new_data.corr().head()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# latitude                 -0.066983   -0.108997   -0.071774      -0.079626
# housing_median_age       -0.320451   -0.295787   -0.302768      -0.118278
# total_rooms               0.930380    0.857281    0.918992       0.197882
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
#
#                     ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# ...

# %%
sns.heatmap(new_data.corr(), annot = True)
plt.show()
plt.figure(figsize = (15, 8 ))

# %%
# scatter plot that use two variables
plt.scatter(df2.median_house_value, df2.median_income, color = 'blue')
plt.show()

# %%
# plotting a scatter plot that use three variables 
sns.scatterplot(x='latitude', y='longitude', data = df2, hue = 'median_house_value', palette = 'coolwarm')
plt.figure(figsize = (15, 8))

# %% [markdown]
# ## TRAINING THE MODEL USING LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# removes the index from the data set and changes it to a one-dimensional array
u = u.squeeze().reset_index(drop = True).values

# %%
new_data.shape
# Out:
# (20433, 13)

# %%
# spliting train and test data for the model.
a_train, a_test, b_train, b_test = train_test_split(new_data, u, train_size = 0.8, random_state = 4)
models = LinearRegression()
models.fit(a_train, b_train)
# Out:
# LinearRegression()

# %%
models.score(a_test, b_test)
# Out:
# 0.6233376876575414

# %% [markdown]
# ## TRAINING MODEL USING RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()
forest.fit(a_train, b_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(a_test, b_test)
# Out:
# 0.8142403472536095
